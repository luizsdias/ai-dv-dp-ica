# %% [markdown]
# <a href="https://colab.research.google.com/github/luizsdias/ai-dv-dp-ica/blob/main/LuizDias_AI_DV_DP_ICA_inPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Data Visualization Tasks**

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/luizsdias/integrated-final-CA/main/forestfires.csv')

# %%
df.head(5)
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
df.shape
# Out:
# (517, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       517 non-null    int64
#  1   Y       517 non-null    int64
#  2   month   517 non-null    object
#  3   day     517 non-null    object
#  4   FFMC    517 non-null    float64
#  5   DMC     517 non-null    float64
#  6   DC      517 non-null    float64
#  7   ISI     517 non-null    float64
#  8   temp    517 non-null    float64
#  9   RH      517 non-null    int64
#  10  wind    517 non-null    float64
#  11  rain    517 non-null    float64
#  12  area    517 non-null    float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 52.6+ KB

# %%
plt.figure(figsize=(10,7))
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x="month", y="ISI", data=df, palette="bright",
                 order=['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'])
ax.set_xlabel('Months', fontsize=15)
ax.set_ylabel('ISI index', fontsize=15)
ax.set_title('ISI Index vs Months', fontsize=18)
plt.show()

# %%
df.loc[df['month'] == 'jun']
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 22   7  4   jun  sun  94.3   96.3  200.0  56.1  21.0  44   4.5   0.0   0.00
# 150  6  5   jun  fri  92.5   56.4  433.3   7.1  23.2  39   5.4   0.0   1.19
# 295  7  5   jun  sun  93.1  180.4  430.8  11.0  22.2  48   1.3   0.0   0.00
# 296  6  4   jun  sun  90.4   89.5  290.8   6.4  14.3  46   1.8   0.0   0.90
# 297  8  6   jun  sun  90.4   89.5  290.8   6.4  15.4  45   2.2   0.0   0.00
# 298  8  6   jun  wed  91.2  147.8  377.2  12.7  19.6  43   4.9   0.0   0.00
# 299  6  5   jun  sat  53.4   71.0  233.8   0.4  10.6  90   2.7   0.0   0.00
# 300  6  5   jun  mon  90.4   93.3  298.1   7.5  20.7  25   4.9   0.0   0.00
# 301  6  5   jun  mon  90.4   93.3  298.1   7.5  19.1  39   5.4   0.0   3.52
# 302  3  6   jun  fri  91.1   94.1  232.1   7.1  19.2  38   4.5   0.0   0.00
# 303  3  6   jun  fri  91.1   94.1  232.1   7.1  19.2  38   4.5   0.0   0.00
# ...

# %%
df.drop([22], inplace = True)

# %%
plt.figure(figsize=(10,7))
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x="month", y="ISI", data=df, palette="bright",
                 order=['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'])
ax.set_xlabel('Months', fontsize=15)
ax.set_ylabel('ISI index', fontsize=15)
ax.set_title('ISI Index vs Months', fontsize=18)
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.set_theme(style="whitegrid")
ax = sns.stripplot(x="month", y="FFMC", data=df, s=10,
                   order=['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'])
ax.set_xlabel('Months', fontsize=15)
ax.set_ylabel('FFMC index', fontsize=15)
ax.set_title('FFMC index vs Months', fontsize=18)
plt.show()

# %%
#@title <-- Run the code. This command was used to find the row index to be dropped.
df.loc[df['month'] == 'jan']
# Out:
#      X  Y month  day  FFMC  DMC     DC  ISI  temp   RH  wind  rain  area
# 104  2  4   jan  sat  82.1  3.7    9.3  2.9   5.3   78   3.1   0.0   0.0
# 379  4  5   jan  sun  18.7  1.1  171.4  0.0   5.2  100   0.9   0.0   0.0

# %%
#@title <-- Run the code. This command was used to drop the row 379.
df.drop([379], inplace = True)

# %%
plt.figure(figsize=(10,7))
sns.set_theme(style="whitegrid")
ax = sns.stripplot(x="month", y="FFMC", data=df, s=10,
                   order=['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'])
ax.set_xlabel('Months', fontsize=15)
ax.set_ylabel('FFMC index', fontsize=15)
ax.set_title('FFMC index vs Months', fontsize=18)
plt.show()

# %%
fig = plt.figure(figsize = (10,8))
df['area'].hist(bins=10)

# %%
fig = plt.figure(figsize = (10,8))
df_burnedarea['area'].hist(bins=10)

# %%
# Not used
df['coordinate'] = df['X'].astype(str) + "," + df['Y'].astype(str)
df.head(5)
# Out:
#    X  Y month  day  FFMC   DMC  ...  temp  RH  wind  rain  area  coordinate
# 0  7  5   mar  fri  86.2  26.2  ...   8.2  51   6.7   0.0   0.0         7,5
# 1  7  4   oct  tue  90.6  35.4  ...  18.0  33   0.9   0.0   0.0         7,4
# 2  7  4   oct  sat  90.6  43.7  ...  14.6  33   1.3   0.0   0.0         7,4
# 3  8  6   mar  fri  91.7  33.3  ...   8.3  97   4.0   0.2   0.0         8,6
# 4  8  6   mar  sun  89.3  51.3  ...  11.4  99   1.8   0.0   0.0         8,6
#
# [5 rows x 14 columns]

# %%
# Not used
df_location = df.loc[df['month'] == 'jun']
df_location
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 22   7  4   jun  sun  94.3   96.3  200.0  56.1  21.0  44   4.5   0.0   0.00
# 150  6  5   jun  fri  92.5   56.4  433.3   7.1  23.2  39   5.4   0.0   1.19
# 295  7  5   jun  sun  93.1  180.4  430.8  11.0  22.2  48   1.3   0.0   0.00
# 296  6  4   jun  sun  90.4   89.5  290.8   6.4  14.3  46   1.8   0.0   0.90
# 297  8  6   jun  sun  90.4   89.5  290.8   6.4  15.4  45   2.2   0.0   0.00
# 298  8  6   jun  wed  91.2  147.8  377.2  12.7  19.6  43   4.9   0.0   0.00
# 299  6  5   jun  sat  53.4   71.0  233.8   0.4  10.6  90   2.7   0.0   0.00
# 300  6  5   jun  mon  90.4   93.3  298.1   7.5  20.7  25   4.9   0.0   0.00
# 301  6  5   jun  mon  90.4   93.3  298.1   7.5  19.1  39   5.4   0.0   3.52
# 302  3  6   jun  fri  91.1   94.1  232.1   7.1  19.2  38   4.5   0.0   0.00
# 303  3  6   jun  fri  91.1   94.1  232.1   7.1  19.2  38   4.5   0.0   0.00
# ...

# %%
df.drop([22], inplace = True)

# %%
df_burnedarea = df.loc[df['area'] != 0.00]
df_burnedarea.head(10)
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area
# 138  9  9   jul  tue  85.8   48.3  313.4   3.9  18.0  42   2.7   0.0  0.36
# 139  1  4   sep  tue  91.0  129.5  692.6   7.0  21.7  38   2.2   0.0  0.43
# 140  2  5   sep  mon  90.9  126.5  686.5   7.0  21.9  39   1.8   0.0  0.47
# 141  1  2   aug  wed  95.5   99.9  513.3  13.2  23.3  31   4.5   0.0  0.55
# 142  8  6   aug  fri  90.1  108.0  529.8  12.5  21.2  51   8.9   0.0  0.61
# 143  1  2   jul  sat  90.0   51.3  296.3   8.7  16.6  53   5.4   0.0  0.71
# 144  2  5   aug  wed  95.5   99.9  513.3  13.2  23.8  32   5.4   0.0  0.77
# 145  6  5   aug  thu  95.2  131.7  578.8  10.4  27.4  22   4.0   0.0  0.90
# 146  5  4   mar  mon  90.1   39.7   86.6   6.2  13.2  40   5.4   0.0  0.95
# 147  8  3   sep  tue  84.4   73.4  671.9   3.2  24.2  28   3.6   0.0  0.96

# %%
plt.figure(figsize=(12,8))
result1 = df_test.pivot(index='Y', columns='X', values='area')
ax = sns.heatmap(result1, annot=True, fmt="g", cmap='YlOrRd')
ax.set_xlabel('Map X Coordinate', fontsize=15)
ax.set_ylabel('Map Y Coordinate', fontsize=15)
ax.set_title('Areas(ha) destroyed by fires at their locations in the park', fontsize=18)
plt.show()

# %%
from calendar import month_abbr

lower_ma = [m.lower() for m in month_abbr]

# one-liner with Pandas
df['month'] = df['month'].str.lower().map(lambda m: lower_ma.index(m)).astype('Int8')

# %%
fig = plt.figure(figsize = (20,8))
df_test.hist(bins=20)
plt.xlim(xmin=0.0, xmax = 1100)
# Out:
# (0.0, 1100.0)

# %%
results = df.groupby('day').sum()
results
# Out:
#        X    Y    FFMC      DMC       DC  ...    temp    RH   wind  rain     area
# day                                      ...
# fri  388  354  7725.2   9276.9  46374.5  ...  1525.6  3966  382.0   1.6   447.24
# mon  362  323  6648.4   6954.3  38169.7  ...  1254.4  3305  276.6   0.0   706.53
# sat  403  362  7593.5   9268.7  44363.8  ...  1625.3  3646  315.7   0.0  2144.86
# sun  430  410  8512.4  10857.7  51983.3  ...  1811.2  4652  391.7   1.0   959.93
# thu  285  268  5595.3   7698.8  35567.8  ...  1202.0  2367  226.4   0.0   997.10
# tue  288  264  5811.8   7096.0  36265.2  ...  1244.1  2795  273.4   8.4   807.79
# wed  258  242  4976.7   6168.6  30560.7  ...  1103.1  2166  211.3   0.2   578.60
#
# [7 rows x 11 columns]

# %%
months = [month for month, df in df.groupby('month')]

#months = range(1, 13)
plt.bar(months, results['rain'])
plt.xticks(months)
plt.xlabel('Months')
plt.ylabel('Rain')
plt.show()

# %%
df_test = df_burnedarea.groupby(['X', 'Y'])[['area']].sum().reset_index()
df_test
# Out:
#     X  Y     area
# 0   1  2   219.94
# 1   1  3   157.14
# 2   1  4   150.28
# 3   1  5   115.47
# 4   2  2   462.65
# 5   2  4   143.37
# 6   2  5    92.63
# 7   3  3     6.58
# 8   3  4   126.35
# 9   3  5     2.18
# 10  4  3   172.88
# 11  4  4   397.43
# 12  4  5   287.01
# 13  4  6    87.73
# 14  5  4    73.75
# 15  5  6    17.62
# 16  6  3   192.78
# 17  6  4   144.47
# 18  6  5  1384.05
# 19  6  6     8.59
# 20  7  3    27.35
# 21  7  4   474.37
# 22  7  5    77.39
# 23  7  6    86.45
# 24  8  3    26.31
# 25  8  4    12.18
# 26  8  5     2.93
# 27  8  6  1265.30
# 28  8  8   185.76
# 29  9  4   185.61
# 30  9  5     8.16
# 31  9  6    42.87
# 32  9  9     4.47

# %%
df.loc[df['month'] == "dec"].count()
# Out:
# X        9
# Y        9
# month    9
# day      9
# FFMC     9
# DMC      9
# DC       9
# ISI      9
# temp     9
# RH       9
# wind     9
# rain     9
# area     9
# dtype: int64

# %%
df['day'] = pd.Categorical(df['day'],
                            categories=['mon', 'tue', 'wed', 'thu', 'fri', 'sat', 'sun'],
                            ordered=True)
sns.stripplot(x='day', y='month', data=df, jitter=True, hue='area', dodge=True, palette="bright")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-cb84f575ea10> in <module>()
#       2                             categories=['mon', 'tue', 'wed', 'thu', 'fri', 'sat', 'sun'],
#       3                             ordered=True)
# ----> 4 sns.stripplot(x='day', y='month', data=df, jitter=True, hue='area', dodge=True, palette="bright")
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in stripplot(x, y, hue, data, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2820                        linewidth=linewidth))
#    2821
# ...

# %%
sns.scatterplot(df['X'], df['Y'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_test2 = df.groupby(['X', 'Y'])[['area']].sum().reset_index()

# %%
plt.figure(figsize=(12,8))
result2 = df_test2.pivot(index='Y', columns='X', values='area')
ax = sns.heatmap(result2, annot=True, fmt="g", cmap='YlOrRd')
ax.set_xlabel('Map X Coordinate', fontsize=15)
ax.set_ylabel('Map Y Coordinate', fontsize=15)
ax.set_title('Areas(ha) destroyed by fires at their locations in the park', fontsize=18)
plt.show()

# %% [markdown]
# ## **Artificial Intelligence Tasks**

# %%
import sys
sys.path.append('/content/csp_abstraction/')
from csp import Constraint, CSP

# %%
from typing import Dict, List, Optional

class OfficeAssigningConstraint(Constraint[str, str]):
    def __init__(self, place1: str, place2: str) -> None:
        super().__init__([place1, place2])
        self.place1: str = place1
        self.place2: str = place2

    def satisfied(self, assignment: Dict[str, str]) -> bool:
        # If either place is not in the assignment, then it is not
        # yet possible for their colors to be conflicting
        if self.place1 not in assignment or self.place2 not in assignment:
            return True
        # check the color assigned to place1 is not the same as the
        # color assigned to place2
        return assignment[self.place1] != assignment[self.place2]

# %%
if __name__ == "__main__":
    variables: List[str] = ["Phylis", "Eva", "Mark", "Bob", "Henry", "Bill", "Ann"]
    domains: Dict[str, List[str]] = {}
    for variable in variables:
        domains[variable] = ["Office 1", "Office 2", "Office 3", "Office 4"]
        
    csp: CSP[str, str] = CSP(variables, domains)
    csp.add_constraint(OfficeAssigningConstraint("Phylis", "Eva"))
    csp.add_constraint(OfficeAssigningConstraint("Mark", "Eva"))
    csp.add_constraint(OfficeAssigningConstraint("Eva", "Bill"))
    csp.add_constraint(OfficeAssigningConstraint("Bill", "Phylis"))
    csp.add_constraint(OfficeAssigningConstraint("Henry", "Phylis"))
    csp.add_constraint(OfficeAssigningConstraint("Ann", "Phylis"))
    csp.add_constraint(OfficeAssigningConstraint("Ann", "Eva"))
    csp.add_constraint(OfficeAssigningConstraint("Ann", "Bill"))
    
    solution: Optional[Dict[str, str]] = csp.backtracking_search()
    if solution is None:
        print("No solution found!")
    else:
        print(solution)
# Out:
# {'Phylis': 'Office 1', 'Eva': 'Office 2', 'Mark': 'Office 1', 'Bob': 'Office 1', 'Henry': 'Office 2', 'Bill': 'Office 3', 'Ann': 'Office 4'}
